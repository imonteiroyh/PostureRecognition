# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle

import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from skopt import BayesSearchCV
from skopt.space import Real, Integer

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, classification_report, auc, ConfusionMatrixDisplay, confusion_matrix

# %%
features_data = pd.read_csv('features_dataset.csv', index_col='Unnamed: 0')
features_data
# Out:
#       trunk_rotated  trunk_angle  trunk_neck_angle  neck_rotated  neck_angle  \
# 0             False   -12.652557        164.621133         False    2.726311
# 1             False   -15.575580        162.662029         False    1.762391
# 2             False   -12.965854        165.271755         False    1.762391
# 3             False   -15.972132        164.882965         False   -0.855097
# 4             False   -14.083207        165.916793         False    0.000000
# ...             ...          ...               ...           ...         ...
# 999           False   -36.511056        124.074408          True         NaN
# 1000          False   -33.578814        132.606161         False   13.815025
# 1001          False   -34.077195        121.640547          True         NaN
# 1002          False   -33.801973         45.217377          True         NaN
# 1003          False   -33.358242        121.041180          True         NaN
#
#       left_upper_arm_angle  right_upper_arm_angle  left_elbow_lateral  \
# 0                      NaN               4.994930               False
# 1                 3.340916               1.934466               False
# 2                95.016823               1.447090               False
# 3                 2.045408               0.460378               False
# 4                94.014176               2.935079               False
# ...                    ...                    ...                 ...
# 999               7.848869               6.584291               False
# 1000              9.659083               4.005279               False
# 1001              1.877877              10.937249               False
# 1002              7.712980               0.432855               False
# 1003              1.389715              12.646844               False
#
#       right_elbow_lateral  left_elbow_angle  right_elbow_angle  \
# 0                   False               NaN         117.448095
# 1                   False        118.765124                NaN
# 2                   False         33.570642         122.647888
# 3                   False        123.009165         136.770369
# 4                   False         33.146996         121.200515
# ...                   ...               ...                ...
# 999                 False        119.046617         159.401103
# 1000                False        123.754517         104.563287
# 1001                False        102.142583         119.687835
# 1002                False        120.924912          99.263552
# 1003                False         98.291271         123.779963
#
#       left_thigh_horizontal  right_thigh_horizontal  left_thigh_angle  \
# 0                      True                   False        115.788245
# 1                     False                    True        109.801427
# 2                      True                    True        116.237576
# 3                      True                    True        111.057290
# 4                      True                    True        117.661293
# ...                     ...                     ...               ...
# 999                    True                    True        131.027862
# 1000                   True                    True        132.836774
# 1001                   True                    True        134.168224
# 1002                   True                    True        133.487912
# 1003                   True                    True        132.871104
#
#       right_thigh_angle  left_knee_angle  right_knee_angle  \
# 0            109.636855       108.188880         95.586732
# 1            120.980451        95.684195        113.092922
# 2            110.891171       108.795887         95.860740
# 3            121.198162        94.346163        112.932100
# 4            113.097418       108.800467         96.825738
# ...                 ...              ...               ...
# 999          146.181004        92.743002        100.109877
# 1000         134.382812        96.873458         94.121014
# 1001         135.879713        93.692613        101.309932
# 1002         134.975164        96.958847         94.319894
# 1003         135.031953        93.218622        101.192245
#
#                                          file  class
# 0             2023-06-03 17_22_13.112711.jpeg  False
# 1     2023-06-03 17_22_13.112711_flipped.jpeg  False
# 2             2023-06-03 17_22_17.757394.jpeg  False
# 3     2023-06-03 17_22_17.757394_flipped.jpeg  False
# 4             2023-06-03 17_22_22.021098.jpeg  False
# ...                                       ...    ...
# 999   2023-06-03 17_43_12.454900_flipped.jpeg   True
# 1000          2023-06-03 17_43_15.425038.jpeg   True
# 1001  2023-06-03 17_43_15.425038_flipped.jpeg   True
# 1002          2023-06-03 17_43_18.604325.jpeg   True
# 1003  2023-06-03 17_43_18.604325_flipped.jpeg   True
#
# [1004 rows x 19 columns]

# %%
target = features_data['class']
print('target:', target.shape)
data = features_data.drop(['file', 'class'], axis=1)
print('data:', data.shape)
# Out:
# target: (1004,)
# data: (1004, 17)

# %%
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size=0.2, random_state=34, shuffle=True, stratify=target)
print('data train:', data_train.shape)
print('data test:', data_test.shape)
print('target train:', target_train.shape)
print('target test:', target_test.shape)
# Out:
# data train: (803, 17)
# data test: (201, 17)
# target train: (803,)
# target test: (201,)

# %%
knn_imputer = KNNImputer()
mm_scaler = MinMaxScaler()

columns = ['trunk_rotated', 'neck_rotated', 'left_thigh_horizontal', 'right_thigh_horizontal']
pipeline = Pipeline(
    [
        ('knn_imputer', knn_imputer),
        ('min_max_scaler', mm_scaler)
    ]
)

X = pipeline.fit_transform(data_train)
data_train = pd.DataFrame(X, columns=data_train.columns)
data_train
# Out:
#      trunk_rotated  trunk_angle  trunk_neck_angle  neck_rotated  neck_angle  \
# 0              0.0     0.159797          0.976993           0.0    0.977735
# 1              0.0     0.165099          0.000000           1.0    0.740008
# 2              0.0     0.506562          0.960807           0.0    0.428330
# 3              0.0     0.514456          0.935944           0.0    0.481715
# 4              0.0     0.323676          0.872572           0.0    0.405168
# ..             ...          ...               ...           ...         ...
# 798            0.0     0.520386          0.903282           0.0    0.547371
# 799            0.0     0.487316          0.911163           0.0    0.499632
# 800            0.0     0.995902          0.962492           0.0    0.918577
# 801            1.0     0.242594          0.822501           1.0    0.267935
# 802            1.0     0.385472          0.344161           1.0    0.840727
#
#      left_upper_arm_angle  right_upper_arm_angle  left_elbow_lateral  \
# 0                0.064755               0.026933                 0.0
# 1                0.046488               0.002317                 0.0
# 2                0.233845               0.166389                 0.0
# 3                0.090540               0.046606                 0.0
# 4                0.365338               0.366676                 0.0
# ..                    ...                    ...                 ...
# 798              0.079714               0.008859                 0.0
# 799              0.062531               0.018385                 0.0
# 800              0.131952               0.130744                 0.0
# 801              0.104437               0.067296                 0.0
# 802              0.135238               0.125121                 0.0
#
#      right_elbow_lateral  left_elbow_angle  right_elbow_angle  \
# 0                    0.0          0.888380           0.770940
# 1                    0.0          0.668455           0.527577
# 2                    0.0          0.354176           0.381850
# 3                    0.0          0.537605           0.564377
# 4                    0.0          0.960324           0.929158
# ..                   ...               ...                ...
# 798                  0.0          0.567345           0.715339
# 799                  0.0          0.603956           0.496782
# 800                  0.0          0.357086           0.325864
# 801                  0.0          0.597349           0.674171
# 802                  0.0          0.761023           0.607200
#
#      left_thigh_horizontal  right_thigh_horizontal  left_thigh_angle  \
# 0                      1.0                     1.0          0.834350
# 1                      1.0                     1.0          0.794601
# 2                      0.0                     1.0          0.519045
# 3                      1.0                     1.0          0.586472
# 4                      1.0                     1.0          0.722747
# ..                     ...                     ...               ...
# 798                    1.0                     1.0          0.569400
# 799                    1.0                     1.0          0.641924
# 800                    0.0                     0.0          0.193393
# 801                    1.0                     1.0          0.658594
# 802                    0.0                     0.0          0.535939
#
#      right_thigh_angle  left_knee_angle  right_knee_angle
# 0             0.685262         0.540647          0.488960
# 1             0.698785         0.494345          0.439737
# 2             0.509654         0.561542          0.503595
# 3             0.542229         0.514624          0.546272
# 4             0.586509         0.441823          0.395337
# ..                 ...              ...               ...
# 798           0.540373         0.521239          0.545313
# 799           0.504950         0.624288          0.492023
# 800           0.153341         0.508530          0.511924
# 801           0.575628         0.371899          0.274581
# 802           0.336133         0.509929          0.487229
#
# [803 rows x 17 columns]

# %%
X = pipeline.transform(data_test)
data_test = pd.DataFrame(X, columns=data_test.columns)
data_test
# Out:
#      trunk_rotated  trunk_angle  trunk_neck_angle  neck_rotated  neck_angle  \
# 0              0.0     0.490662          0.912663           0.0    0.500266
# 1              0.0     0.509948          0.962676           0.0    0.428330
# 2              0.0     0.160524          0.915222           0.0    0.162764
# 3              0.0     0.506461          0.898321           0.0    0.542396
# 4              0.0     0.319073          0.860868           0.0    0.421912
# ..             ...          ...               ...           ...         ...
# 196            0.0     0.497141          0.911976           0.0    0.508053
# 197            1.0     0.361580          0.199620           1.0    0.779567
# 198            0.0     0.335003          0.871283           0.0    0.418944
# 199            0.0     0.556470          0.957088           0.0    0.485440
# 200            1.0     0.507073          0.953144           1.0    0.463399
#
#      left_upper_arm_angle  right_upper_arm_angle  left_elbow_lateral  \
# 0                0.065526               0.012116                 0.0
# 1                0.095809               0.009418                 0.0
# 2                0.189130               0.112360                 0.0
# 3                0.055347               0.005595                 0.0
# 4                0.312411               0.375844                 0.0
# ..                    ...                    ...                 ...
# 196              0.086132               0.047785                 0.0
# 197              0.222758               0.107063                 0.0
# 198              0.372854               0.363499                 0.0
# 199              0.022038               0.088796                 0.0
# 200              0.026258               0.093626                 0.0
#
#      right_elbow_lateral  left_elbow_angle  right_elbow_angle  \
# 0                    0.0          0.599417           0.496659
# 1                    0.0          0.590498           0.812490
# 2                    0.0          0.798856           0.728903
# 3                    0.0          0.579014           0.492326
# 4                    1.0          0.946522           0.949965
# ..                   ...               ...                ...
# 196                  0.0          0.570536           0.683029
# 197                  0.0          0.412881           0.393982
# 198                  0.0          0.902283           0.950352
# 199                  0.0          0.501286           0.516965
# 200                  0.0          0.707221           0.499134
#
#      left_thigh_horizontal  right_thigh_horizontal  left_thigh_angle  \
# 0                      1.0                     1.0          0.639784
# 1                      1.0                     1.0          0.574747
# 2                      1.0                     1.0          0.787364
# 3                      1.0                     0.0          0.593317
# 4                      1.0                     1.0          0.724417
# ..                     ...                     ...               ...
# 196                    1.0                     1.0          0.596025
# 197                    1.0                     0.0          0.659471
# 198                    1.0                     1.0          0.722867
# 199                    0.0                     0.0          0.543811
# 200                    1.0                     1.0          0.612932
#
#      right_thigh_angle  left_knee_angle  right_knee_angle
# 0             0.499655         0.623011          0.491256
# 1             0.567465         0.530971          0.575642
# 2             0.707379         0.481153          0.684563
# 3             0.459906         0.565146          0.482181
# 4             0.590281         0.439241          0.394170
# ..                 ...              ...               ...
# 196           0.564393         0.522735          0.545025
# 197           0.449600         0.539844          0.481572
# 198           0.594955         0.424127          0.419405
# 199           0.453260         0.527050          0.586304
# 200           0.499853         0.582371          0.482042
#
# [201 rows x 17 columns]

# %%
classifier = xgb.XGBClassifier(random_state=34)

cross_validation = StratifiedKFold(n_splits=10, shuffle=True, random_state=34)

def bayesian_search_callback(results):

    all_scores = results['func_vals']

    best_score = results['fun']
    best_parameters = results['x']

    current_parameters = results['x_iters']

    print(f'Model #{len(all_scores)}:')
    print(f'Current Score: {-all_scores[-1]}')
    print(f'Current Parameters: {current_parameters[-1]}')
    print(f'Best Score: {-best_score}')
    print(f'Best Parameters: {best_parameters}\n')

space = {
    'n_estimators': Integer(100, 200),
    'max_depth': Integer(1, 25),
    'learning_rate': Real(1e-4, 1e-1, 'log-uniform'),
    'gamma': Real(0.05, 1.0),
    'min_child_weight': Integer(1, 50),
    'subsample': Real(0.05, 1.0),
    'colsample_bytree': Real(0.06, 1.0)
}

optimization = BayesSearchCV(
    classifier,
    space,
    n_iter=100,
    cv=cross_validation,
    random_state=34,
    n_jobs=-1,
    scoring='f1',
    return_train_score=True,
    refit=True
)

optimization.fit(data_train, target_train, callback=[bayesian_search_callback])

print(f'Best Parameters: {optimization.best_params_}')
print(f'Best Score: {optimization.best_score_}')
print(f'Best Estimator: {optimization.best_estimator_}')
# Out:
# Model #1:
# Current Score: 0.9895047399857525
# Current Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #2:
# Current Score: 0.9780859824164289
# Current Parameters: [0.914872574013454, 0.1820706565185377, 0.0005036156126553225, 24, 9, 115, 0.5931573862041036]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #3:
# Current Score: 0.897457003406261
# Current Parameters: [0.19238790589325003, 0.9769039266392116, 0.0031419725073038667, 7, 47, 151, 0.6057047185873693]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #4:
# Current Score: 0.8925594044497341
# Current Parameters: [0.0915876370504449, 0.24481606353181679, 0.0019407749549453551, 18, 47, 113, 0.6047879484934634]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #5:
# Current Score: 0.0
# Current Parameters: [0.6541595677772258, 0.40644496965653254, 0.0001763458219277699, 4, 44, 134, 0.16488212500539026]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #6:
# Current Score: 0.0
# Current Parameters: [0.34789026977469556, 0.9158013521694811, 0.010030460870723606, 23, 50, 155, 0.1708168761849396]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #7:
# Current Score: 0.0
# Current Parameters: [0.7612813685411923, 0.4919000403391292, 0.01066018859037393, 11, 48, 182, 0.11556524881003938]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #8:
# Current Score: 0.0
# Current Parameters: [0.6893060318864828, 0.06772091450251819, 0.04173957920271963, 2, 49, 181, 0.38112034692688235]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #9:
# Current Score: 0.8985717132578129
# Current Parameters: [0.845211300602986, 0.6834311455368347, 0.01404388670689939, 18, 42, 191, 0.7222765595611462]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #10:
# Current Score: 0.9032036860343652
# Current Parameters: [0.07438998814041478, 0.9891650618442132, 0.09571151929695489, 20, 45, 116, 0.6490932476895074]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #11:
# Current Score: 0.9258228631898422
# Current Parameters: [0.6947871482865915, 1.0, 0.007541331442684265, 1, 1, 142, 0.5626462464283644]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #12:
# Current Score: 0.8894305186824946
# Current Parameters: [0.9530746628752615, 1.0, 0.0006317690502629327, 1, 47, 200, 0.9908986659656797]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #13:
# Current Score: 0.9883655603655603
# Current Parameters: [0.47034421020786965, 1.0, 0.1, 1, 1, 200, 0.9375113579711057]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #14:
# Current Score: 0.9673571682592336
# Current Parameters: [0.06, 1.0, 0.1, 1, 18, 200, 0.8623621565408406]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #15:
# Current Score: 0.9301405135405301
# Current Parameters: [0.17767965978804187, 1.0, 0.1, 1, 22, 200, 0.5847502877092963]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #16:
# Current Score: 0.9856423918076148
# Current Parameters: [0.7699258568176084, 0.05, 0.0001, 25, 1, 100, 0.7927202605787265]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #17:
# Current Score: 0.9042685607012585
# Current Parameters: [0.7020416331116641, 0.05, 0.0001, 24, 50, 100, 0.9057327703199132]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #18:
# Current Score: 0.9869410931063161
# Current Parameters: [0.12735188216817117, 0.05, 0.1, 1, 1, 100, 0.860652705969722]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #19:
# Current Score: 0.9854280294585479
# Current Parameters: [0.06, 1.0, 0.0001, 22, 1, 200, 0.8822538243787083]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #20:
# Current Score: 0.9311508429842965
# Current Parameters: [0.14195754602711347, 0.05, 0.0004053090521459412, 1, 1, 100, 0.6640887861243392]
# Best Score: 0.9895047399857525
# Best Parameters: [0.2685312423103485, 0.2959959195329342, 0.007819993682661562, 3, 11, 102, 0.5550599996753738]
#
# Model #21:
# Current Score: 0.9921007385817513
# Current Parameters: [0.06, 0.05, 0.1, 25, 1, 100, 1.0]
# Best Score: 0.9921007385817513
# Best Parameters: [0.06, 0.05, 0.1, 25, 1, 100, 1.0]
#
# Model #22:
# Current Score: 0.9934705636357867
# Current Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #23:
# Current Score: 0.9856775136921705
# Current Parameters: [1.0, 1.0, 0.1, 6, 9, 200, 1.0]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #24:
# Current Score: 0.9830463562642111
# Current Parameters: [1.0, 1.0, 0.0001, 5, 1, 118, 0.3904817109466352]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #25:
# Current Score: 0.9858712117206453
# Current Parameters: [1.0, 1.0, 0.1, 1, 7, 200, 0.8101465940856442]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #26:
# Current Score: 0.9773159780147267
# Current Parameters: [0.06, 1.0, 0.0009169876816677117, 21, 1, 200, 0.22304027616755384]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #27:
# Current Score: 0.9815744597396827
# Current Parameters: [0.06, 1.0, 0.07204995005064059, 1, 1, 200, 0.30237659457866445]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #28:
# Current Score: 0.9307194527297792
# Current Parameters: [0.06, 1.0, 0.1, 1, 1, 100, 0.05]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #29:
# Current Score: 0.971589523623168
# Current Parameters: [1.0, 1.0, 0.1, 1, 23, 200, 1.0]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #30:
# Current Score: 0.975715810394358
# Current Parameters: [0.9799178986752488, 1.0, 0.0028125773791470854, 25, 8, 200, 0.48884145770560417]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #31:
# Current Score: 0.9807496617306743
# Current Parameters: [1.0, 1.0, 0.1, 1, 14, 200, 0.7170578327742669]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #32:
# Current Score: 0.9229555223752424
# Current Parameters: [1.0, 1.0, 0.1, 1, 31, 200, 0.9076243225948477]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #33:
# Current Score: 0.9029461182309054
# Current Parameters: [0.5894774018152431, 1.0, 0.00012181892453474705, 1, 50, 200, 0.7394654135146947]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #34:
# Current Score: 0.9883103904756135
# Current Parameters: [0.6443640776017818, 0.05, 0.1, 1, 1, 200, 0.14104082390995537]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #35:
# Current Score: 0.9856779352115794
# Current Parameters: [1.0, 1.0, 0.1, 25, 13, 200, 0.941193600680199]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #36:
# Current Score: 0.9673221155926021
# Current Parameters: [0.06, 1.0, 0.1, 1, 14, 200, 0.6397379379591076]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #37:
# Current Score: 0.97451418667941
# Current Parameters: [1.0, 1.0, 0.1, 25, 19, 200, 0.7708534223519585]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #38:
# Current Score: 0.9843436905089135
# Current Parameters: [1.0, 0.05, 0.0001, 25, 4, 100, 0.9659198872213595]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #39:
# Current Score: 0.8835389240242071
# Current Parameters: [1.0, 1.0, 0.0001, 1, 1, 200, 1.0]
# Best Score: 0.9934705636357867
# Best Parameters: [0.9945525394382708, 1.0, 0.1, 25, 1, 191, 0.8273244473570674]
#
# Model #40:
# Current Score: 0.9946998946998947
# Current Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #41:
# Current Score: 0.9883090926395388
# Current Parameters: [0.5563567172964178, 0.05, 0.1, 25, 9, 100, 1.0]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #42:
# Current Score: 0.8939100623521868
# Current Parameters: [1.0, 0.9379968429878212, 0.0001, 25, 23, 100, 0.9165414779101706]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #43:
# Current Score: 0.0
# Current Parameters: [0.2841611513803701, 0.9370593891788936, 0.0021583271579618873, 1, 43, 149, 0.12896443052965145]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #44:
# Current Score: 0.9830108128602465
# Current Parameters: [1.0, 0.05, 0.0001384058494463617, 25, 6, 100, 0.9377044557968736]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #45:
# Current Score: 0.9908994398804525
# Current Parameters: [0.06, 0.05, 0.1, 25, 5, 100, 0.930828829918881]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #46:
# Current Score: 0.9163241912505942
# Current Parameters: [0.06, 1.0, 0.0001, 1, 20, 100, 0.6602217619143448]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #47:
# Current Score: 0.9934376851218956
# Current Parameters: [0.47578701807099233, 0.05, 0.1, 25, 3, 200, 0.8885950860019074]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #48:
# Current Score: 0.985746287911511
# Current Parameters: [1.0, 0.05, 0.1, 18, 1, 100, 0.2137396019618637]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #49:
# Current Score: 0.9645782965619334
# Current Parameters: [1.0, 0.7576757355674593, 0.0001, 18, 9, 100, 0.5004985635809559]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #50:
# Current Score: 0.9869735159355411
# Current Parameters: [0.06, 0.05, 0.1, 25, 9, 116, 0.7722967294603251]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #51:
# Current Score: 0.972042465748288
# Current Parameters: [1.0, 0.05, 0.1, 23, 11, 100, 0.5569115938052399]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #52:
# Current Score: 0.8948904935765931
# Current Parameters: [1.0, 1.0, 0.1, 25, 50, 200, 1.0]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #53:
# Current Score: 0.986907793073016
# Current Parameters: [1.0, 0.05, 0.1, 25, 6, 157, 0.9507387171568996]
# Best Score: 0.9946998946998947
# Best Parameters: [0.16408894954994135, 0.05, 0.1, 25, 3, 100, 0.9361343959794735]
#
# Model #54:
# Current Score: 0.9961021425831552
# Current Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #55:
# Current Score: 0.97605217005217
# Current Parameters: [0.06, 0.05, 0.0001, 24, 7, 200, 0.7511357925794784]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #56:
# Current Score: 0.9961021425831552
# Current Parameters: [0.8530896190155726, 0.05, 0.1, 25, 1, 100, 0.903966075484594]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #57:
# Current Score: 0.983079165560178
# Current Parameters: [0.3319651559823401, 0.16540263619528778, 0.0001, 25, 1, 100, 0.14179998523650097]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #58:
# Current Score: 0.9896077597729829
# Current Parameters: [0.06, 0.05, 0.1, 1, 1, 200, 0.44041384877190254]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #59:
# Current Score: 0.9921718623370854
# Current Parameters: [0.8597774862069807, 0.05, 0.1, 25, 1, 100, 0.36306547655978233]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #60:
# Current Score: 0.9896401826022079
# Current Parameters: [0.06, 0.05, 0.1, 25, 16, 100, 1.0]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #61:
# Current Score: 0.9830108128602465
# Current Parameters: [1.0, 0.05, 0.0006117932385985444, 25, 5, 100, 0.8460593709831474]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #62:
# Current Score: 0.9750768852421082
# Current Parameters: [0.06, 0.05, 0.1, 1, 5, 126, 0.40859943132402743]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #63:
# Current Score: 0.9871694573346804
# Current Parameters: [0.889032866754071, 1.0, 0.1, 1, 1, 200, 0.38131470027113235]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #64:
# Current Score: 0.9691437899533195
# Current Parameters: [0.06, 0.05, 0.0019435159398388802, 25, 1, 100, 0.42321889962667714]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #65:
# Current Score: 0.9921007385817513
# Current Parameters: [0.06, 0.05, 0.1, 25, 1, 100, 0.9189432112588795]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #66:
# Current Score: 0.9830463562642111
# Current Parameters: [0.9857399518193375, 0.05, 0.0001, 21, 1, 179, 0.3149124939191726]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #67:
# Current Score: 0.9948038969691201
# Current Parameters: [0.9951698110963108, 0.05, 0.1, 25, 1, 200, 0.7619475197575906]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #68:
# Current Score: 0.9869433364769806
# Current Parameters: [1.0, 0.9838741042512272, 0.1, 25, 6, 120, 0.7271838246472907]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #69:
# Current Score: 0.9921011601011601
# Current Parameters: [0.06, 1.0, 0.1, 25, 1, 200, 0.78967643844457]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #70:
# Current Score: 0.8806260111078901
# Current Parameters: [1.0, 0.05, 0.0001, 1, 1, 100, 0.16469448069791764]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #71:
# Current Score: 0.9895047399857525
# Current Parameters: [0.06, 0.05, 0.1, 25, 1, 200, 0.11176234257552348]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #72:
# Current Score: 0.9443360830188515
# Current Parameters: [0.06, 0.05, 0.0001, 25, 1, 200, 0.05]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #73:
# Current Score: 0.9818470643280769
# Current Parameters: [1.0, 0.9452405964947681, 0.0020657114885407404, 25, 1, 185, 0.9306474218956893]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #74:
# Current Score: 0.9541469707612462
# Current Parameters: [0.06, 0.07593329842725864, 0.0006756337251002866, 25, 18, 200, 0.5807742378576074]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #75:
# Current Score: 0.9869433364769806
# Current Parameters: [1.0, 0.05, 0.1, 13, 5, 200, 0.46419746834254305]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #76:
# Current Score: 0.9103822994233951
# Current Parameters: [0.6843907401737876, 0.058223064546232856, 0.0015883421372243033, 1, 10, 200, 0.4965183336485703]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #77:
# Current Score: 0.9920692640692639
# Current Parameters: [0.06, 0.05, 0.1, 5, 1, 100, 0.414632847139224]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #78:
# Current Score: 0.9947363864205968
# Current Parameters: [0.31398848826828313, 1.0, 0.0001, 25, 1, 100, 0.41237077526614746]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #79:
# Current Score: 0.9744501766153999
# Current Parameters: [0.8603996674432641, 0.6537502836161357, 0.009236395053491548, 25, 11, 100, 0.5711069955914703]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #80:
# Current Score: 0.9679282725934959
# Current Parameters: [1.0, 0.05, 0.1, 1, 15, 100, 0.6222601030307979]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #81:
# Current Score: 0.9948038969691201
# Current Parameters: [1.0, 0.05, 0.1, 11, 1, 100, 0.7562872007570075]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #82:
# Current Score: 0.9920678600678601
# Current Parameters: [0.15534654061124165, 1.0, 0.007120128933723486, 25, 1, 169, 0.14696413707818845]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #83:
# Current Score: 0.968514989101265
# Current Parameters: [0.06, 1.0, 0.1, 1, 9, 117, 0.5487605779685247]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #84:
# Current Score: 0.981780533479401
# Current Parameters: [0.7931509131295342, 0.05, 0.007989526638681651, 13, 9, 100, 0.7237455806095868]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #85:
# Current Score: 0.9688504945347051
# Current Parameters: [0.06, 0.05, 0.0001, 25, 1, 100, 0.5077088542462309]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #86:
# Current Score: 0.9856423918076148
# Current Parameters: [1.0, 0.05, 0.1, 12, 4, 100, 0.8952165832566847]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #87:
# Current Score: 0.973416485265919
# Current Parameters: [0.1082368961189836, 0.11290893431192049, 0.006003700099540293, 25, 1, 100, 0.7618111965397225]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #88:
# Current Score: 0.9649187169523612
# Current Parameters: [0.4705206801584387, 0.05, 0.1, 25, 29, 166, 1.0]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #89:
# Current Score: 0.9870116891769122
# Current Parameters: [0.37038566107614174, 1.0, 0.0039919491758128155, 8, 13, 100, 0.603890727518841]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #90:
# Current Score: 0.9735351600161725
# Current Parameters: [0.06, 0.05, 0.1, 1, 5, 104, 0.7319505198663487]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #91:
# Current Score: 0.9948038969691201
# Current Parameters: [1.0, 0.05, 0.1, 14, 1, 200, 0.8028070948024849]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #92:
# Current Score: 0.9857076931507309
# Current Parameters: [0.06, 1.0, 0.1, 15, 1, 200, 0.15659112966213984]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #93:
# Current Score: 0.9018691560782404
# Current Parameters: [0.06, 0.21297297170745744, 0.1, 1, 50, 100, 0.7356086040773717]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #94:
# Current Score: 0.9920692640692639
# Current Parameters: [0.06, 0.5453620700759775, 0.1, 25, 1, 100, 0.4575953172954052]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #95:
# Current Score: 0.9858102914185525
# Current Parameters: [0.06, 1.0, 0.1, 25, 5, 139, 0.43910567862320493]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #96:
# Current Score: 0.9870054119674373
# Current Parameters: [0.06, 0.7402865149365935, 0.0019158474777173418, 25, 11, 200, 1.0]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #97:
# Current Score: 0.9819138317822528
# Current Parameters: [1.0, 0.2514353386377855, 0.1, 12, 12, 100, 0.7697679511178672]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #98:
# Current Score: 0.9666594658949755
# Current Parameters: [1.0, 0.05, 0.1, 25, 1, 100, 0.05]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #99:
# Current Score: 0.9844422918853297
# Current Parameters: [0.06, 1.0, 0.0001, 25, 10, 171, 1.0]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Model #100:
# Current Score: 0.9830108128602465
# Current Parameters: [1.0, 1.0, 0.0001, 4, 2, 116, 0.8020940553135827]
# Best Score: 0.9961021425831552
# Best Parameters: [0.2896037300749497, 0.05, 0.1, 25, 1, 154, 0.4082522295451273]
#
# Best Parameters: OrderedDict([('colsample_bytree', 0.2896037300749497), ('gamma', 0.05), ('learning_rate', 0.1), ('max_depth', 25), ('min_child_weight', 1), ('n_estimators', 154), ('subsample', 0.4082522295451273)])
# Best Score: 0.9961021425831552
# Best Estimator: XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1,
#               colsample_bytree=0.2896037300749497, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.05, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.1, max_bin=256, max_cat_threshold=64,
#               max_cat_to_onehot=4, max_delta_step=0, max_depth=25, max_leaves=0,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=154, n_jobs=0, num_parallel_tree=1, predictor='auto',
#               random_state=34, ...)

# %%
target_predicted = optimization.best_estimator_.predict(data_test)
target_predicted_prob = optimization.best_estimator_.predict_proba(data_test)

# %%
precision, recall, threshold = precision_recall_curve(target_test, target_predicted_prob[:, 1])
print(classification_report(target_test, target_predicted))
print(f'AUC: {round(auc(recall, precision), 2)}')
conf_matrix = confusion_matrix(target_test, target_predicted)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=optimization.classes_)
disp.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       104
#         True       0.98      1.00      0.99        97
#
#     accuracy                           0.99       201
#    macro avg       0.99      0.99      0.99       201
# weighted avg       0.99      0.99      0.99       201
#
# AUC: 1.0

# %%
file = 'posture_classification/pipeline.pkl'
pickle.dump(pipeline, open(file, 'wb'))

file = 'posture_classification/classifier.pkl'
pickle.dump(optimization.best_estimator_, open(file, 'wb'))
